# %% [markdown]
# # Discovery of Non-Linear Double Pendulum Dynamics using SODAs: Plotting

# %%
import os, sys

path_to_add = os.path.abspath(os.path.join(os.getcwd(), "../../"))
sys.path.append(path_to_add)
print(os.path.join(path_to_add, "daeFinder"))
sys.path.append(os.path.join(path_to_add, "daeFinder"))


import numpy as np
from scipy.integrate import odeint
import pandas as pd
import warnings
pd.set_option('display.float_format', '{:0.8f}'.format)
import operator
import sympy
from dae_finder import construct_reduced_fit_list

import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp




from matplotlib import pyplot as plt
from dae_finder import smooth_data
from dae_finder import add_noise_to_df
from sklearn import decomposition
from sklearn.linear_model import LinearRegression
from dae_finder import get_simplified_equation_list
from dae_finder import get_refined_lib, remove_paranth_from_feat
from dae_finder import AlgModelFinder
from dae_finder import sequentialThLin, AlgModelFinder
from dae_finder import PolyFeatureMatrix
from copy import deepcopy
# Out:
# /Users/manujayadharan/git_repos/DAE-FINDER_dev/daeFinder

# %%
xls = pd.ExcelFile('pendulum_data_requirement.xlsx')

df_dict = {sheet_name: xls.parse(sheet_name) for sheet_name in xls.sheet_names}

# %%
plt.figure()
marker_list = ['o', '^', 'o']
color_list = ['#332288', '#332288', '#88CCEB']
plt.figure(figsize=(7, 7))
for key, marker, color in zip(df_dict, marker_list, color_list):
    if key == "Pendulum experiment video":
        continue
    df = df_dict[key]
    plt.plot(df["Polynomial Degree"][:4], df["num data points"][:4], marker=marker, color=color, label=key)

# plt.title('Polynomial Degree vs Num Data Points')
# plt.xlabel('Polynomial Degree')
# plt.ylabel('Num of Frames Per Footage')
plt.xticks([2, 3, 4, 5])
plt.grid(True)
plt.legend(fontsize=15)
plt.savefig('Example_2_data_requirement.svg', format='svg')
plt.show()
